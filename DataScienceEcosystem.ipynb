# %% [markdown]
# # Title Data Science Tools and Ecosystem

# %% [markdown]
# ### In this notebook, Data Science Tools and Ecosystem are summarized.

# %% [markdown]
# # Some of the commonly used libraries used by Data Scientists include:
# - 1. Pandas,
# - 2. Numpy,
# - 3. Seaborn

# %% [markdown]
# # Data Science Tools:
# - 1.Jupyter Notebook
# - 2.RStudio
# - 3.Spyder

# %% [markdown]
# ##  Below are a few examples of evaluating arithmetic expressions in Python
# - Addition: 5 + 3 results in 8
#
# - Multiplication: 4 * 2.5 results in 10.0
#
# - Division (Float): 10 / 3 results in approximately 3.333
#
# - Exponentiation: 2 ** 4 results in 16

# %%
(3 * 4)+ 5
# This a simple arithmetic expression to mutiply then add integ
# Out:
# 17

# %%
# This will convert 200 minutes to hours by dividing by 60.
200 / 60
# Out:
# 3.3333333333333335

# %% [markdown]
# ### Objectives:
#
# - <b> Identify open-source development environment tools (e.g., Jupyter Notebook, RStudio).
#
# - <b> Perform basic arithmetic operations in Python.
#
# - <b> Understand and apply fundamental Markdown formatting in notebook cells.

# %% [markdown]
# ## Author
# <b> Biplab MONDAL
